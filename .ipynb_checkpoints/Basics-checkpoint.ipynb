# %% [markdown]
# # Analysing DETE employee exit surveys

# %% [markdown]
# In this project, I'm going to clean up and analyse data gathered from __[Departament of Education, Training and Employment](https://en.wikipedia.org/wiki/Department_of_Education_(Queensland))__ (DETE) and the Technical and Further Education (TAFE) institute in Queensland, Australia.
#
# The data was collected __[here](https://data.gov.au/dataset/ds-qld-fe96ff30-d157-4a81-851d-215f2a0fe26d/details?q=exit%20survey)__. Original data was encoded using cp1253, I'm using slightly modified version converted to UTF-8.
#
# I'm going to combine both datasets, raising two main questions for this analysis:
#  - Are employees who only worked for the institutes for a short period of time resigning due to some kind of dissatisfaction? What about employees who have been there longer?
#  - Are younger employees resigning due to some kind of dissatisfaction? What about older employees?

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import re
# %matplotlib inline

# %%
dete_survey = pd.read_csv('dete_survey.csv')
dete_survey.head()
# Out:
#    ID                    SeparationType Cease Date DETE Start Date  \
# 0   1             Ill Health Retirement    08/2012            1984
# 1   2  Voluntary Early Retirement (VER)    08/2012      Not Stated
# 2   3  Voluntary Early Retirement (VER)    05/2012            2011
# 3   4         Resignation-Other reasons    05/2012            2005
# 4   5                    Age Retirement    05/2012            1970
#
#   Role Start Date                                      Position  \
# 0            2004                                Public Servant
# 1      Not Stated                                Public Servant
# 2            2011                               Schools Officer
# 3            2006                                       Teacher
# 4            1989  Head of Curriculum/Head of Special Education
#
#   Classification              Region                      Business Unit  \
# 0        A01-A04      Central Office  Corporate Strategy and Peformance
# ...

# %%
dete_survey.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 822 entries, 0 to 821
# Data columns (total 56 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   ID                                   822 non-null    int64
#  1   SeparationType                       822 non-null    object
#  2   Cease Date                           822 non-null    object
#  3   DETE Start Date                      822 non-null    object
#  4   Role Start Date                      822 non-null    object
#  5   Position                             817 non-null    object
#  6   Classification                       455 non-null    object
#  7   Region                               822 non-null    object
#  8   Business Unit                        126 non-null    object
#  9   Employment Status                    817 non-null    object
#  10  Career move to public sector         822 non-null    bool
# ...

# %%
tafe_survey = pd.read_csv('tafe_survey.csv')
tafe_survey.head()
# Out:
#       Record ID                              Institute  \
# 0  6.341330e+17  Southern Queensland Institute of TAFE
# 1  6.341337e+17            Mount Isa Institute of TAFE
# 2  6.341388e+17            Mount Isa Institute of TAFE
# 3  6.341399e+17            Mount Isa Institute of TAFE
# 4  6.341466e+17  Southern Queensland Institute of TAFE
#
#                    WorkArea  CESSATION YEAR Reason for ceasing employment  \
# 0  Non-Delivery (corporate)          2010.0              Contract Expired
# 1  Non-Delivery (corporate)          2010.0                    Retirement
# 2       Delivery (teaching)          2010.0                    Retirement
# 3  Non-Delivery (corporate)          2010.0                   Resignation
# 4       Delivery (teaching)          2010.0                   Resignation
#
#   Contributing Factors. Career Move - Public Sector   \
# 0                                                NaN
# 1                                                  -
# ...

# %%
tafe_survey.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 702 entries, 0 to 701
# Data columns (total 72 columns):
#  #   Column                                                                                                                                                         Non-Null Count  Dtype
# ---  ------                                                                                                                                                         --------------  -----
#  0   Record ID                                                                                                                                                      702 non-null    float64
#  1   Institute                                                                                                                                                      702 non-null    object
# ...

# %% [markdown]
# ## Overview of the dataset
# Data is formatted very differently between the datasets, but looking into the DETE dataset I saw a couple of columns, that would be suitable for further analysis answering the two questions I've raised for this project:
#  - ID: The id used to identify the participant
#  - SeparationType: Why this person left DETE
#  - Cease Date: The last day the person worked at DETE
#  - DETE Start Date: Year the person started working at DETE
#
# TAFE dataset while formatted very differently does provide us with simmilar information to further work on:
#  - Record ID: The id used to identify the participant
#  - Reason for ceasing employment: Why this person left TAFE
#  - LengthofServiceOverall. Overall Length of Service at Institute (in years): How many years the person worked at TAFE

# %% [markdown]
# ### Steps to clean up the data
#
# In the DETE dataset we can see that several columns contain entries with "Not Stated" data. This data can be read as NaN, since it is not useful to us and essentially means the same thing.
#
# Both Datasets contain mostly the same columns, but the column names are different, we can standardize the column names.

# %%
dete_survey = pd.read_csv('dete_survey.csv', na_values="Not Stated")
dete_survey.head()
# Out:
#    ID                    SeparationType Cease Date  DETE Start Date  \
# 0   1             Ill Health Retirement    08/2012           1984.0
# 1   2  Voluntary Early Retirement (VER)    08/2012              NaN
# 2   3  Voluntary Early Retirement (VER)    05/2012           2011.0
# 3   4         Resignation-Other reasons    05/2012           2005.0
# 4   5                    Age Retirement    05/2012           1970.0
#
#    Role Start Date                                      Position  \
# 0           2004.0                                Public Servant
# 1              NaN                                Public Servant
# 2           2011.0                               Schools Officer
# 3           2006.0                                       Teacher
# 4           1989.0  Head of Curriculum/Head of Special Education
#
#   Classification              Region                      Business Unit  \
# 0        A01-A04      Central Office  Corporate Strategy and Peformance
# ...

# %%
dete_survey.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 822 entries, 0 to 821
# Data columns (total 56 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   ID                                   822 non-null    int64
#  1   SeparationType                       822 non-null    object
#  2   Cease Date                           788 non-null    object
#  3   DETE Start Date                      749 non-null    float64
#  4   Role Start Date                      724 non-null    float64
#  5   Position                             817 non-null    object
#  6   Classification                       455 non-null    object
#  7   Region                               717 non-null    object
#  8   Business Unit                        126 non-null    object
#  9   Employment Status                    817 non-null    object
#  10  Career move to public sector         822 non-null    bool
# ...

# %%
dete_survey.isnull().sum()
# Out:
# ID                                       0
# SeparationType                           0
# Cease Date                              34
# DETE Start Date                         73
# Role Start Date                         98
# Position                                 5
# Classification                         367
# Region                                 105
# Business Unit                          696
# Employment Status                        5
# Career move to public sector             0
# Career move to private sector            0
# Interpersonal conflicts                  0
# Job dissatisfaction                      0
# Dissatisfaction with the department      0
# Physical work environment                0
# Lack of recognition                      0
# Lack of job security                     0
# Work location                            0
# Employment conditions                    0
# Maternity/family                         0
# Relocation                               0
# ...

# %%
print(tafe_survey.isnull().sum())
# Out:
# Record ID                                                                      0
# Institute                                                                      0
# WorkArea                                                                       0
# CESSATION YEAR                                                                 7
# Reason for ceasing employment                                                  1
#                                                                             ...
# CurrentAge. Current Age                                                      106
# Employment Type. Employment Type                                             106
# Classification. Classification                                               106
# LengthofServiceOverall. Overall Length of Service at Institute (in years)    106
# LengthofServiceCurrent. Length of Service at current workplace (in years)    106
# Length: 72, dtype: int64

# %%
dete_survey_updated = dete_survey.drop(dete_survey.columns[28:49], axis=1)
dete_survey_updated.head()
# Out:
#    ID                    SeparationType Cease Date  DETE Start Date  \
# 0   1             Ill Health Retirement    08/2012           1984.0
# 1   2  Voluntary Early Retirement (VER)    08/2012              NaN
# 2   3  Voluntary Early Retirement (VER)    05/2012           2011.0
# 3   4         Resignation-Other reasons    05/2012           2005.0
# 4   5                    Age Retirement    05/2012           1970.0
#
#    Role Start Date                                      Position  \
# 0           2004.0                                Public Servant
# 1              NaN                                Public Servant
# 2           2011.0                               Schools Officer
# 3           2006.0                                       Teacher
# 4           1989.0  Head of Curriculum/Head of Special Education
#
#   Classification              Region                      Business Unit  \
# 0        A01-A04      Central Office  Corporate Strategy and Peformance
# ...

# %%
tafe_survey_updated = tafe_survey.drop(tafe_survey.columns[17:66], axis=1)
tafe_survey_updated.head()
# Out:
#       Record ID                              Institute  \
# 0  6.341330e+17  Southern Queensland Institute of TAFE
# 1  6.341337e+17            Mount Isa Institute of TAFE
# 2  6.341388e+17            Mount Isa Institute of TAFE
# 3  6.341399e+17            Mount Isa Institute of TAFE
# 4  6.341466e+17  Southern Queensland Institute of TAFE
#
#                    WorkArea  CESSATION YEAR Reason for ceasing employment  \
# 0  Non-Delivery (corporate)          2010.0              Contract Expired
# 1  Non-Delivery (corporate)          2010.0                    Retirement
# 2       Delivery (teaching)          2010.0                    Retirement
# 3  Non-Delivery (corporate)          2010.0                   Resignation
# 4       Delivery (teaching)          2010.0                   Resignation
#
#   Contributing Factors. Career Move - Public Sector   \
# 0                                                NaN
# 1                                                  -
# ...

# %% [markdown]
# ### Renaming Columns
# Dropping columns, that did not provide useful data for the two questions raised. Checking to make sure that the columns were dropped and then I'll standardize the remaining columns of both datasets, to make combining them easier.

# %%
print(dete_survey_updated.columns)
# Out:
# Index(['ID', 'SeparationType', 'Cease Date', 'DETE Start Date',
#        'Role Start Date', 'Position', 'Classification', 'Region',
#        'Business Unit', 'Employment Status', 'Career move to public sector',
#        'Career move to private sector', 'Interpersonal conflicts',
#        'Job dissatisfaction', 'Dissatisfaction with the department',
#        'Physical work environment', 'Lack of recognition',
#        'Lack of job security', 'Work location', 'Employment conditions',
#        'Maternity/family', 'Relocation', 'Study/Travel', 'Ill Health',
#        'Traumatic incident', 'Work life balance', 'Workload',
#        'None of the above', 'Gender', 'Age', 'Aboriginal', 'Torres Strait',
#        'South Sea', 'Disability', 'NESB'],
#       dtype='object')

# %%
print(tafe_survey_updated.columns)
# Out:
# Index(['Record ID', 'Institute', 'WorkArea', 'CESSATION YEAR',
#        'Reason for ceasing employment',
#        'Contributing Factors. Career Move - Public Sector ',
#        'Contributing Factors. Career Move - Private Sector ',
#        'Contributing Factors. Career Move - Self-employment',
#        'Contributing Factors. Ill Health',
#        'Contributing Factors. Maternity/Family',
#        'Contributing Factors. Dissatisfaction',
#        'Contributing Factors. Job Dissatisfaction',
#        'Contributing Factors. Interpersonal Conflict',
#        'Contributing Factors. Study', 'Contributing Factors. Travel',
#        'Contributing Factors. Other', 'Contributing Factors. NONE',
#        'Gender. What is your Gender?', 'CurrentAge. Current Age',
#        'Employment Type. Employment Type', 'Classification. Classification',
#        'LengthofServiceOverall. Overall Length of Service at Institute (in years)',
# ...

# %%
dete_survey_updated.columns = dete_survey_updated.columns.str.replace(' ', '_').str.lower().str.strip()
print(dete_survey_updated.columns)
# Out:
# Index(['id', 'separationtype', 'cease_date', 'dete_start_date',
#        'role_start_date', 'position', 'classification', 'region',
#        'business_unit', 'employment_status', 'career_move_to_public_sector',
#        'career_move_to_private_sector', 'interpersonal_conflicts',
#        'job_dissatisfaction', 'dissatisfaction_with_the_department',
#        'physical_work_environment', 'lack_of_recognition',
#        'lack_of_job_security', 'work_location', 'employment_conditions',
#        'maternity/family', 'relocation', 'study/travel', 'ill_health',
#        'traumatic_incident', 'work_life_balance', 'workload',
#        'none_of_the_above', 'gender', 'age', 'aboriginal', 'torres_strait',
#        'south_sea', 'disability', 'nesb'],
#       dtype='object')

# %%
tafe_column_map = {'Record ID':'id','CESSATION YEAR':'cease_date',
                   'Reason for ceasing employment':'separationtype',
                   'Gender. What is your Gender?':'gender',
                   'CurrentAge. Current Age':'age',
                   'Employment Type. Employment Type':'employment_status',
                   'Classification. Classification':'position',
                   'LengthofServiceOverall. Overall Length of Service at Institute (in years)':'institute_service',
                   'LengthofServiceCurrent. Length of Service at current workplace (in years)':'role_service'}
tafe_survey_updated = tafe_survey_updated.rename(tafe_column_map, axis='columns')
print(tafe_survey_updated.columns)
# Out:
# Index(['id', 'Institute', 'WorkArea', 'cease_date', 'separationtype',
#        'Contributing Factors. Career Move - Public Sector ',
#        'Contributing Factors. Career Move - Private Sector ',
#        'Contributing Factors. Career Move - Self-employment',
#        'Contributing Factors. Ill Health',
#        'Contributing Factors. Maternity/Family',
#        'Contributing Factors. Dissatisfaction',
#        'Contributing Factors. Job Dissatisfaction',
#        'Contributing Factors. Interpersonal Conflict',
#        'Contributing Factors. Study', 'Contributing Factors. Travel',
#        'Contributing Factors. Other', 'Contributing Factors. NONE', 'gender',
#        'age', 'employment_status', 'position', 'institute_service',
#        'role_service'],
#       dtype='object')

# %% [markdown]
# I've standardized the main columns of both datasets to be in snake case and lowercase. For the DETE dataset I've also removed any leading or trailing spaces. TAFE dataset didn't have the same pattern to the column names, and most of them were quite wordy, so I've decided that the best course of action here is to simply map to new names instead of working with the existing ones.
#
# ### Filtering remaining Data

# %%
dete_survey_updated.head()
# Out:
#    id                    separationtype cease_date  dete_start_date  \
# 0   1             Ill Health Retirement    08/2012           1984.0
# 1   2  Voluntary Early Retirement (VER)    08/2012              NaN
# 2   3  Voluntary Early Retirement (VER)    05/2012           2011.0
# 3   4         Resignation-Other reasons    05/2012           2005.0
# 4   5                    Age Retirement    05/2012           1970.0
#
#    role_start_date                                      position  \
# 0           2004.0                                Public Servant
# 1              NaN                                Public Servant
# 2           2011.0                               Schools Officer
# 3           2006.0                                       Teacher
# 4           1989.0  Head of Curriculum/Head of Special Education
#
#   classification              region                      business_unit  \
# 0        A01-A04      Central Office  Corporate Strategy and Peformance
# ...

# %%
tafe_survey_updated.head()
# Out:
#              id                              Institute  \
# 0  6.341330e+17  Southern Queensland Institute of TAFE
# 1  6.341337e+17            Mount Isa Institute of TAFE
# 2  6.341388e+17            Mount Isa Institute of TAFE
# 3  6.341399e+17            Mount Isa Institute of TAFE
# 4  6.341466e+17  Southern Queensland Institute of TAFE
#
#                    WorkArea  cease_date    separationtype  \
# 0  Non-Delivery (corporate)      2010.0  Contract Expired
# 1  Non-Delivery (corporate)      2010.0        Retirement
# 2       Delivery (teaching)      2010.0        Retirement
# 3  Non-Delivery (corporate)      2010.0       Resignation
# 4       Delivery (teaching)      2010.0       Resignation
#
#   Contributing Factors. Career Move - Public Sector   \
# 0                                                NaN
# 1                                                  -
# 2                                                  -
# 3                                                  -
# ...

# %%
dete_survey_updated['separationtype'].value_counts()
# Out:
# Age Retirement                          285
# Resignation-Other reasons               150
# Resignation-Other employer               91
# Resignation-Move overseas/interstate     70
# Voluntary Early Retirement (VER)         67
# Ill Health Retirement                    61
# Other                                    49
# Contract Expired                         34
# Termination                              15
# Name: separationtype, dtype: int64

# %%
tafe_survey_updated['separationtype'].value_counts()
# Out:
# Resignation                 340
# Contract Expired            127
# Retrenchment/ Redundancy    104
# Retirement                   82
# Transfer                     25
# Termination                  23
# Name: separationtype, dtype: int64

# %% [markdown]
# Both questions I've raised for this analysis revolve around resignation of the Employees. DETE and TAFE surveys provide us with data about resignation in the *separationtype* column. Here we have to be careful, as the DETE survey contains three types of resignation, while TAFE has only one:
#  - Resignation-Other reasons
#  - Resignation-Other employer
#  - Resignation-Move overseas/interstate

# %%
dete_resignations = dete_survey_updated[(dete_survey_updated['separationtype']=='Resignation-Other reasons') |
                                       (dete_survey_updated['separationtype']=='Resignation-Other employer') |
                                       (dete_survey_updated['separationtype']=='Resignation-Move overseas/interstate')]
dete_resignations.head()
# Out:
#     id                        separationtype cease_date  dete_start_date  \
# 3    4             Resignation-Other reasons    05/2012           2005.0
# 5    6             Resignation-Other reasons    05/2012           1994.0
# 8    9             Resignation-Other reasons    07/2012           2009.0
# 9   10            Resignation-Other employer       2012           1997.0
# 11  12  Resignation-Move overseas/interstate       2012           2009.0
#
#     role_start_date          position classification                region  \
# 3            2006.0           Teacher        Primary    Central Queensland
# 5            1997.0  Guidance Officer            NaN        Central Office
# 8            2009.0           Teacher      Secondary      North Queensland
# 9            2008.0      Teacher Aide            NaN                   NaN
# 11           2009.0           Teacher      Secondary  Far North Queensland
#
#            business_unit    employment_status  ...  work_life_balance  \
# ...

# %%
tafe_resignations = tafe_survey_updated[tafe_survey_updated['separationtype']=='Resignation']
tafe_resignations.head()
# Out:
#              id                              Institute  \
# 3  6.341399e+17            Mount Isa Institute of TAFE
# 4  6.341466e+17  Southern Queensland Institute of TAFE
# 5  6.341475e+17  Southern Queensland Institute of TAFE
# 6  6.341520e+17         Barrier Reef Institute of TAFE
# 7  6.341537e+17  Southern Queensland Institute of TAFE
#
#                    WorkArea  cease_date separationtype  \
# 3  Non-Delivery (corporate)      2010.0    Resignation
# 4       Delivery (teaching)      2010.0    Resignation
# 5       Delivery (teaching)      2010.0    Resignation
# 6  Non-Delivery (corporate)      2010.0    Resignation
# 7       Delivery (teaching)      2010.0    Resignation
#
#   Contributing Factors. Career Move - Public Sector   \
# 3                                                  -
# 4                                                  -
# 5                                                  -
# 6                                                  -
# ...

# %% [markdown]
# Since my interest is only in the "resignation" data from both datasets, I've created two subsets of the data, where only entries detailing employees with *separationtype* containing "Resignation" remain.
#
# ### Verifying the remaining Data
#
# DETE dataset contains data about when the employee started working at DETE (column *dete_start_date*) and data about employee ceasing the working relationship with DETE (column *cease_date*) it would make sense that:
#  - Cease date would be later than the Start date
#  - Cease date would be after current date
#  - Start date was after 1940
#
# *1940 was selected considering most people start working in their 20s. People that started in 1940 would have been born at least in the 1920s and would be over 90 years old, it is unlikely there are many older people working at DETE.*

# %%
dete_resignations['cease_date'].value_counts(ascending=True)
# Out:
# 07/2012      1
# 09/2010      1
# 07/2006      1
# 2010         1
# 05/2012      2
# 05/2013      2
# 08/2013      4
# 10/2013      6
# 07/2013      9
# 11/2013      9
# 09/2013     11
# 06/2013     14
# 12/2013     17
# 01/2014     22
# 2013        74
# 2012       126
# Name: cease_date, dtype: int64

# %% [markdown]
# We can see here, that cease date values are inconsistent. I'm only interested in the year value, so I can clean up the rest by splitting the string and converting the year to a float value to match *dete_start_date*.

# %%
dete_resignations['cease_date'] = dete_resignations['cease_date'].str.split('/').str[-1].astype('float')
dete_resignations['cease_date'].value_counts().sort_index(ascending=True)
# Out:
# <ipython-input-23-758334e0c2de>:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# 2006.0      1
# 2010.0      2
# 2012.0    129
# 2013.0    146
# 2014.0     22
# Name: cease_date, dtype: int64

# %%
dete_resignations['dete_start_date'].value_counts().sort_index(ascending=True)
# Out:
# 1963.0     1
# 1971.0     1
# 1972.0     1
# 1973.0     1
# 1974.0     2
# 1975.0     1
# 1976.0     2
# 1977.0     1
# 1980.0     5
# 1982.0     1
# 1983.0     2
# 1984.0     1
# 1985.0     3
# 1986.0     3
# 1987.0     1
# 1988.0     4
# 1989.0     4
# 1990.0     5
# 1991.0     4
# 1992.0     6
# 1993.0     5
# 1994.0     6
# 1995.0     4
# 1996.0     6
# 1997.0     5
# 1998.0     6
# 1999.0     8
# 2000.0     9
# 2001.0     3
# 2002.0     6
# 2003.0     6
# 2004.0    14
# 2005.0    15
# 2006.0    13
# 2007.0    21
# 2008.0    22
# 2009.0    13
# 2010.0    17
# 2011.0    24
# 2012.0    21
# 2013.0    10
# Name: dete_start_date, dtype: int64

# %%
tafe_resignations['cease_date'].value_counts().sort_index(ascending=True)
# Out:
# 2009.0      2
# 2010.0     68
# 2011.0    116
# 2012.0     94
# 2013.0     55
# Name: cease_date, dtype: int64

# %%
tafe_bplot = tafe_resignations.boxplot(column='cease_date')
tafe_bplot.plot()
plt.title("TAFE dataset cease date distribution")
plt.ylim(1940, 2014)
plt.show()

# %%
dete_bplot = dete_resignations.boxplot(column=['dete_start_date','cease_date'])
dete_bplot.plot()
plt.title("DETE dataset start and Cease date distribution")
plt.ylim(1940, 2014)
plt.show()

# %%
dete_wrong_data = dete_resignations[dete_resignations['cease_date']<dete_resignations['dete_start_date']]
dete_wrong_data.head()
# Out:
# Empty DataFrame
# Columns: [id, separationtype, cease_date, dete_start_date, role_start_date, position, classification, region, business_unit, employment_status, career_move_to_public_sector, career_move_to_private_sector, interpersonal_conflicts, job_dissatisfaction, dissatisfaction_with_the_department, physical_work_environment, lack_of_recognition, lack_of_job_security, work_location, employment_conditions, maternity/family, relocation, study/travel, ill_health, traumatic_incident, work_life_balance, workload, none_of_the_above, gender, age, aboriginal, torres_strait, south_sea, disability, nesb]
# Index: []
#
# [0 rows x 35 columns]

# %% [markdown]
# Analysis shows that:
#  - There is no data before 1940 (in fact the oldest entries are from 1963)
#  - There is no data after 2014
#  - No rows contain data where cease date is before start date.
#
# This means that I can move forward with the data as-is, and I don't need to remove or fix any date related values.
#
# One notable thing, is that DETE and TAFE datasets do not cover the same number of years. But this can be ignored as it does not really affect the two questions I've raised at the start of the analysis.

# %% [markdown]
# #### Measuring the length of service
# TAFE dataset contains *institute_service* column, which provide us with lenght of time the employee worked at TAFE. In order to compare I'll create the same column for DETE datasource, from the data I've alredy have in columns *cease_date* and *dete_start_date*.

# %%
dete_resignations.insert(2, 'institute_service', (dete_resignations['cease_date'] - dete_resignations['dete_start_date']))
dete_resignations.head()
# Out:
#     id                        separationtype  institute_service  cease_date  \
# 3    4             Resignation-Other reasons                7.0      2012.0
# 5    6             Resignation-Other reasons               18.0      2012.0
# 8    9             Resignation-Other reasons                3.0      2012.0
# 9   10            Resignation-Other employer               15.0      2012.0
# 11  12  Resignation-Move overseas/interstate                3.0      2012.0
#
#     dete_start_date  role_start_date          position classification  \
# 3            2005.0           2006.0           Teacher        Primary
# 5            1994.0           1997.0  Guidance Officer            NaN
# 8            2009.0           2009.0           Teacher      Secondary
# 9            1997.0           2008.0      Teacher Aide            NaN
# 11           2009.0           2009.0           Teacher      Secondary
#
#                   region         business_unit  ... work_life_balance  \
# ...

# %% [markdown]
# #### Measuring employee dissatisfaction
# To answer the first question, I have to pick out the employees who resigned due to some kind of dissatisfaction. Need to pick out columns which has the necessery data.

# %%
print(dete_resignations.columns)
# Out:
# Index(['id', 'separationtype', 'institute_service', 'cease_date',
#        'dete_start_date', 'role_start_date', 'position', 'classification',
#        'region', 'business_unit', 'employment_status',
#        'career_move_to_public_sector', 'career_move_to_private_sector',
#        'interpersonal_conflicts', 'job_dissatisfaction',
#        'dissatisfaction_with_the_department', 'physical_work_environment',
#        'lack_of_recognition', 'lack_of_job_security', 'work_location',
#        'employment_conditions', 'maternity/family', 'relocation',
#        'study/travel', 'ill_health', 'traumatic_incident', 'work_life_balance',
#        'workload', 'none_of_the_above', 'gender', 'age', 'aboriginal',
#        'torres_strait', 'south_sea', 'disability', 'nesb'],
#       dtype='object')

# %% [markdown]
# In the DETE dataset we can see a multitude of contributing factors, that could be considered dissatisfaction with the job:
#  - 'job_dissatisfaction',
#  - 'dissatisfaction_with_the_department',
#  - 'physical_work_environment',
#  - 'lack_of_recognition',
#  - 'lack_of_job_security',
#  - 'work_location',
#  - 'employment_conditions',
#  - 'work_life_balance',
#  - 'workload'

# %%
print(tafe_resignations.columns)
# Out:
# Index(['id', 'Institute', 'WorkArea', 'cease_date', 'separationtype',
#        'Contributing Factors. Career Move - Public Sector ',
#        'Contributing Factors. Career Move - Private Sector ',
#        'Contributing Factors. Career Move - Self-employment',
#        'Contributing Factors. Ill Health',
#        'Contributing Factors. Maternity/Family',
#        'Contributing Factors. Dissatisfaction',
#        'Contributing Factors. Job Dissatisfaction',
#        'Contributing Factors. Interpersonal Conflict',
#        'Contributing Factors. Study', 'Contributing Factors. Travel',
#        'Contributing Factors. Other', 'Contributing Factors. NONE', 'gender',
#        'age', 'employment_status', 'position', 'institute_service',
#        'role_service'],
#       dtype='object')

# %% [markdown]
# While in the TAFE datset there are only two:
#  - 'Contributing Factors. Dissatisfaction',
#  - 'Contributing Factors. Job Dissatisfaction'.
#
# I'm going to start with TAFE, as it is the easier dataset to work with in this instance.
#
# I'm going to create a new column, that will have either True or False values. If employee filled in either of the contributing factors I'll mark the dissatisfaction as True.

# %%
tafe_resignations['Contributing Factors. Dissatisfaction'].value_counts(dropna=False)
# Out:
# -                                         277
# Contributing Factors. Dissatisfaction      55
# NaN                                         8
# Name: Contributing Factors. Dissatisfaction, dtype: int64

# %%
tafe_resignations['Contributing Factors. Job Dissatisfaction'].value_counts(dropna=False)
# Out:
# -                      270
# Job Dissatisfaction     62
# NaN                      8
# Name: Contributing Factors. Job Dissatisfaction, dtype: int64

# %% [markdown]
# We can see that both columns contain, either "-", NaN, or some other value, this data needs to be converted into True or False values. I think NaN can be left as is, but "-" will be converted into False, and any other value other than NaN or "-" into True.

# %%
def convert_tafe_values(val_string):
    if val_string == '-':
        return False
    elif pd.isnull(val_string):
        return np.nan
    else:
        return True

# %%
tafe_resignations['Contributing Factors. Job Dissatisfaction'] = tafe_resignations['Contributing Factors. Job Dissatisfaction'].apply(convert_tafe_values)
tafe_resignations['Contributing Factors. Job Dissatisfaction'].value_counts(dropna=False)
# Out:
# <ipython-input-35-a5b08d642cc1>:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# False    270
# True      62
# NaN        8
# Name: Contributing Factors. Job Dissatisfaction, dtype: int64

# %%
tafe_resignations['Contributing Factors. Dissatisfaction'] = tafe_resignations['Contributing Factors. Dissatisfaction'].apply(convert_tafe_values)
tafe_resignations['Contributing Factors. Dissatisfaction'].value_counts(dropna=False)
# Out:
# <ipython-input-36-0cc5b777e580>:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# False    277
# True      55
# NaN        8
# Name: Contributing Factors. Dissatisfaction, dtype: int64

# %%
tafe_resignations.insert(4, 'dissatisfied', tafe_resignations[['Contributing Factors. Dissatisfaction','Contributing Factors. Job Dissatisfaction']].any(axis='columns',skipna=False))
tafe_resignations_up = tafe_resignations.copy()

# %%
tafe_resignations_up['dissatisfied'].value_counts(dropna=False)
# Out:
# False    241
# True      91
# NaN        8
# Name: dissatisfied, dtype: int64

# %% [markdown]
# Let's now do the same for the DETE dataset.

# %%
dete_resignations[['job_dissatisfaction',
'dissatisfaction_with_the_department',
'physical_work_environment',
'lack_of_recognition',
'lack_of_job_security',
'work_location',
'employment_conditions',
'work_life_balance',
'workload']].head()
# Out:
#     job_dissatisfaction  dissatisfaction_with_the_department  \
# 3                 False                                False
# 5                 False                                False
# 8                 False                                False
# 9                  True                                 True
# 11                False                                False
#
#     physical_work_environment  lack_of_recognition  lack_of_job_security  \
# 3                       False                False                 False
# 5                       False                False                 False
# 8                       False                False                 False
# 9                       False                False                 False
# 11                      False                False                 False
#
#     work_location  employment_conditions  work_life_balance  workload
# 3           False                  False              False     False
# ...

# %% [markdown]
# We can see here, that all the columns already match the pattern we set for TAFE dataset, and contain only True, False, or NaN values.

# %%
dete_resignations_up = dete_resignations.copy()
dete_resign_factors = dete_resignations[['job_dissatisfaction',
'dissatisfaction_with_the_department',
'physical_work_environment',
'lack_of_recognition',
'lack_of_job_security',
'work_location',
'employment_conditions',
'work_life_balance',
'workload']].copy()
dete_resignations_up.insert(3, 'dissatisfied', dete_resign_factors.any(axis='columns', skipna=False))
dete_resignations_up['dissatisfied'].value_counts(dropna=False)
# Out:
# False    162
# True     149
# Name: dissatisfied, dtype: int64

# %% [markdown]
# ### Combining the data
# First off, I'll need a way to distinguish between datasets, once the data has been combined, to do this I'll add a column to each dataset with its name, for example DETE dataset will have *institute* column that will be filled with the value 'DETE'.

# %%
dete_resignations_up.insert(37, 'institute', 'DETE')
dete_resignations_up.head()
# Out:
#     id                        separationtype  institute_service  dissatisfied  \
# 3    4             Resignation-Other reasons                7.0         False
# 5    6             Resignation-Other reasons               18.0          True
# 8    9             Resignation-Other reasons                3.0         False
# 9   10            Resignation-Other employer               15.0          True
# 11  12  Resignation-Move overseas/interstate                3.0         False
#
#     cease_date  dete_start_date  role_start_date          position  \
# 3       2012.0           2005.0           2006.0           Teacher
# 5       2012.0           1994.0           1997.0  Guidance Officer
# 8       2012.0           2009.0           2009.0           Teacher
# 9       2012.0           1997.0           2008.0      Teacher Aide
# 11      2012.0           2009.0           2009.0           Teacher
#
#    classification                region  ... workload none_of_the_above  \
# ...

# %%
tafe_resignations_up.insert(24, 'institute', 'TAFE')
tafe_resignations_up.head()
# Out:
#              id                              Institute  \
# 3  6.341399e+17            Mount Isa Institute of TAFE
# 4  6.341466e+17  Southern Queensland Institute of TAFE
# 5  6.341475e+17  Southern Queensland Institute of TAFE
# 6  6.341520e+17         Barrier Reef Institute of TAFE
# 7  6.341537e+17  Southern Queensland Institute of TAFE
#
#                    WorkArea  cease_date dissatisfied separationtype  \
# 3  Non-Delivery (corporate)      2010.0        False    Resignation
# 4       Delivery (teaching)      2010.0        False    Resignation
# 5       Delivery (teaching)      2010.0        False    Resignation
# 6  Non-Delivery (corporate)      2010.0        False    Resignation
# 7       Delivery (teaching)      2010.0        False    Resignation
#
#   Contributing Factors. Career Move - Public Sector   \
# 3                                                  -
# 4                                                  -
# 5                                                  -
# ...

# %%
combined = pd.concat([dete_resignations_up, tafe_resignations_up])
combined.head()
# Out:
#       id                        separationtype institute_service dissatisfied  \
# 3    4.0             Resignation-Other reasons                 7        False
# 5    6.0             Resignation-Other reasons                18         True
# 8    9.0             Resignation-Other reasons                 3        False
# 9   10.0            Resignation-Other employer                15         True
# 11  12.0  Resignation-Move overseas/interstate                 3        False
#
#     cease_date  dete_start_date  role_start_date          position  \
# 3       2012.0           2005.0           2006.0           Teacher
# 5       2012.0           1994.0           1997.0  Guidance Officer
# 8       2012.0           2009.0           2009.0           Teacher
# 9       2012.0           1997.0           2008.0      Teacher Aide
# 11      2012.0           2009.0           2009.0           Teacher
#
#    classification                region  ... Contributing Factors. Ill Health  \
# ...

# %%
combined.notnull().sum().sort_values()
# Out:
# torres_strait                                            0
# south_sea                                                3
# aboriginal                                               7
# disability                                               8
# nesb                                                     9
# business_unit                                           32
# classification                                         161
# region                                                 265
# role_start_date                                        271
# dete_start_date                                        283
# role_service                                           290
# none_of_the_above                                      311
# workload                                               311
# work_life_balance                                      311
# ill_health                                             311
# study/travel                                           311
# ...

# %% [markdown]
# After combining both datasets, it is apparent, that there are many columns where more than half of the values are NaN. Having in mind, that total amount of rows in the datasets is 651, I think  a good cut-off point would be any column, that contains less than 500 non-null values.

# %%
combined_updated = combined.dropna(axis='columns', thresh=500)
combined_updated.notnull().sum().sort_values()
# Out:
# institute_service    563
# gender               592
# age                  596
# employment_status    597
# position             598
# cease_date           635
# dissatisfied         643
# id                   651
# separationtype       651
# institute            651
# dtype: int64

# %%
combined_updated['institute_service'].value_counts()
# Out:
# Less than 1 year      73
# 1-2                   64
# 3-4                   63
# 5-6                   33
# 11-20                 26
# 5.0                   23
# 1.0                   22
# 7-10                  21
# 3.0                   20
# 0.0                   20
# 6.0                   17
# 4.0                   16
# 9.0                   14
# 2.0                   14
# 7.0                   13
# More than 20 years    10
# 13.0                   8
# 8.0                    8
# 20.0                   7
# 15.0                   7
# 14.0                   6
# 17.0                   6
# 12.0                   6
# 10.0                   6
# 22.0                   6
# 18.0                   5
# 16.0                   5
# 24.0                   4
# 23.0                   4
# 11.0                   4
# 39.0                   3
# 19.0                   3
# 21.0                   3
# 32.0                   3
# 36.0                   2
# 25.0                   2
# 26.0                   2
# ...

# %% [markdown]
#  #### Categorizing employees by years of service
#
#  After combining the dataset the *'institute_service'* column is a mess. It contains, float, and string values. To continue with analysis I'll have to clean this column up.
#
# According to [this article](https://www.businesswire.com/news/home/20171108006002/en/Age-Number-Engage-Employees-Career-Stage) there are four distinct categories, that I could fit all of these employee types:
#  - **Newbie**: Employees with 3 years or less of experience at the company.
#  - **Sophomore**: Employees with 4-7 years of experience at the company.
#  - **Tenured**: Employees with 8-10 years of experience at the company.
#  - **Sage**: Employees with 11 years or more of experience at the company.

# %%
combined_updated['institute_service'] = combined_updated['institute_service'].astype('str').str.extract(r'(\d+)').astype('float')
combined_updated['institute_service'].value_counts()
# Out:
# <ipython-input-47-13377b183b35>:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# 1.0     159
# 3.0      83
# 5.0      56
# 7.0      34
# 11.0     30
# 0.0      20
# 20.0     17
# 6.0      17
# 4.0      16
# 9.0      14
# 2.0      14
# 13.0      8
# 8.0       8
# 15.0      7
# 17.0      6
# 10.0      6
# 12.0      6
# 14.0      6
# 22.0      6
# 16.0      5
# 18.0      5
# 24.0      4
# 23.0      4
# 39.0      3
# 19.0      3
# 21.0      3
# 32.0      3
# 28.0      2
# 36.0      2
# 25.0      2
# 30.0      2
# 26.0      2
# 29.0      1
# 38.0      1
# 42.0      1
# 27.0      1
# 41.0      1
# 35.0      1
# 49.0      1
# 34.0      1
# 33.0      1
# 31.0      1
# Name: institute_service, dtype: int64

# %%
def employee_yos_mapper(years):
    if pd.isnull(years):
        return np.nan
    elif years <= 3:
        return 'Newbie'
    elif (years > 3) & (years < 8):
        return 'Sophomore'
    elif (years > 7) & (years < 11):
        return 'Tenured'
    elif years > 10:
        return 'Sage'

# %%
combined_updated.insert(3, 'service_cat', combined_updated['institute_service'].apply(employee_yos_mapper))
combined_updated.head(10)
# Out:
#       id                        separationtype  institute_service service_cat  \
# 3    4.0             Resignation-Other reasons                7.0   Sophomore
# 5    6.0             Resignation-Other reasons               18.0        Sage
# 8    9.0             Resignation-Other reasons                3.0      Newbie
# 9   10.0            Resignation-Other employer               15.0        Sage
# 11  12.0  Resignation-Move overseas/interstate                3.0      Newbie
# 12  13.0             Resignation-Other reasons               14.0        Sage
# 14  15.0            Resignation-Other employer                5.0   Sophomore
# 16  17.0             Resignation-Other reasons                NaN         NaN
# 20  21.0            Resignation-Other employer               30.0        Sage
# 21  22.0             Resignation-Other reasons               32.0        Sage
#
#    dissatisfied  cease_date          position    employment_status  gender  \
# ...

# %% [markdown]
# #### Performing initial analysis
#
# In order to start performing initial analysis of the data I'll need to get rid of the rest of NaN values.

# %%
combined_updated['dissatisfied'].value_counts(dropna=False)
# Out:
# False    403
# True     240
# NaN        8
# Name: dissatisfied, dtype: int64

# %% [markdown]
# Can see here, that there are 8 NaN values in the whole *'dissatisfied'* column. There are almost double False values than there are True values, so I'll fill in the NaN vaulues, with False.

# %%
combined_updated[['dissatisfied']] = combined_updated[['dissatisfied']].fillna(value=False)
combined_updated['dissatisfied'].value_counts(dropna=False)
# Out:
# /dataquest/system/env/python3/lib/python3.8/site-packages/pandas/core/frame.py:2963: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# False    411
# True     240
# Name: dissatisfied, dtype: int64

# %%
table = combined_updated.pivot_table(index='service_cat', values='dissatisfied')
table.plot(kind='bar')
plt.show()

# %% [markdown]
# Can see here, that people who worked the longest 11+ years are exiting the institute due to some kind of dissatisfaction.
# What is notable, that employees who haven't worked there long (less than 3 years) are resigning less due to some dissatisfaction, and more so due to other factors.

# %% [markdown]
#  - Decide how to handle the rest of the missing values. Then, aggregate the data according to the service_cat column again. How many people in each career stage resigned due to some kind of dissatisfaction?
#  - Clean the age column. How many people in each age group resgined due to some kind of dissatisfaction?
#  - Instead of analyzing the survey results together, analyze each survey separately. Did more employees in the DETE survey or TAFE survey end their employment because they were dissatisfied in some way?
#  - Format your project using Dataquest's project style guide.
